# %% [markdown]
# ## TCGA-LUAD (Lung Adenocarcinoma) dataset
# #### Use CCA to identify sets of genes that best differentiate between NSCLC patients and healthy controls, showing genetic factors in NSCLC development.

# %%
import os
import pandas as pd

first_filename = os.path.join("..", 'data', 'illumina', "HiSeqV2")
second_filename = os.path.join("..", 'data', 'phenotypes', "TCGA.LUAD.sampleMap_LUAD_clinicalMatrix")

try: 
    with open(first_filename, "r") as f:
        X1 = pd.read_csv(f, sep="\t", index_col=0)

except FileNotFoundError:
    raise FileNotFoundError(f"File {first_filename} not found.")

try:
    with open(second_filename, "r") as f:
        X2 = pd.read_csv(f, sep="\t", index_col=0)

except FileNotFoundError:
    raise FileNotFoundError(f"File {second_filename} not found.")

# %% [markdown]
# X1: **20,530** rows (genes) and **576** columns (samples)
# Each column corresponds to a patient sample.
# These are TCGA sample IDs, with the **suffix -01 indicating a tumor sample** and -11 often indicating a normal (non-tumor) sample.

# %%
print(f"Shape of Illumina data: {X1.shape}")
print(f"Shape of Phenotype data: {X2.shape}")
print("\n----------------------------------------------")
print(f"First rows of gene expression profiles measured using RNA-Seq;")
print(X1.head())
print("\n----------------------------------------------")
print(f"First rows of clinical data on phenotypes;")
print(X2.head())
# Out:
# Shape of Illumina data: (20530, 576)
# Shape of Phenotype data: (706, 147)
#
# ----------------------------------------------
# First rows of gene expression profiles measured using RNA-Seq;
#            TCGA-69-7978-01  TCGA-62-8399-01  TCGA-78-7539-01  TCGA-50-5931-11  \
# sample
# ARHGEF10L           9.9898          10.4257           9.6264           8.6835
# HIF3A               4.2598          11.6239           9.1362           9.4824
# RNF17               0.4181           0.0000           1.1231           0.8221
# RNF10              10.3657          11.5489          11.6692          11.7341
# RNF11              11.1718          11.0200          10.4679          11.6787
#
#            TCGA-73-4658-01  TCGA-44-6775-01  TCGA-44-2655-01  TCGA-44-3398-01  \
# sample
# ARHGEF10L           9.2078          10.0039           9.3263           9.0249
# HIF3A               5.0288           4.0573           5.5335           5.7347
# RNF17               0.0000           1.0069           0.6021           0.0000
# RNF10              11.6209          11.1721          11.9169          11.3274
# RNF11              11.3414          11.0969          11.4044          11.4975
#
#            TCGA-62-8397-01  TCGA-53-A4EZ-01  ...  TCGA-75-7025-01  \
# sample                                       ...
# ARHGEF10L          10.5411          10.8969  ...          10.0905
# HIF3A               6.6477           8.0041  ...           8.0944
# RNF17               0.0000           0.0000  ...           0.4628
# RNF10              12.3611          12.3762  ...          11.3260
# RNF11              11.2828          10.3068  ...          10.8121
#
#            TCGA-55-7726-01  TCGA-L9-A743-01  TCGA-86-8358-01  TCGA-55-6972-01  \
# sample
# ARHGEF10L           7.5219           9.6563           9.2042           8.2127
# HIF3A               4.2952           5.1675           9.2442           9.0641
# RNF17               0.0000           0.9593           0.7339           1.0987
# RNF10              12.0388          11.4458          11.5642          11.5881
# RNF11              11.3304          10.4473          10.9991          10.0014
#
#            TCGA-55-7727-01  TCGA-91-6831-01  TCGA-MN-A4N4-01  TCGA-55-8302-01  \
# sample
# ARHGEF10L           7.2428           8.8388           9.9341          10.1696
# HIF3A               7.5416           3.5613           8.3457           5.5364
# RNF17               0.9392           0.0000           0.9715           0.0000
# RNF10              11.8686          12.2704          11.8150          11.7813
# RNF11              11.2862          11.1187          10.6101          10.5163
#
#            TCGA-MP-A4TK-01
# sample
# ARHGEF10L          10.1272
# HIF3A              10.2122
# RNF17               0.5804
# RNF10              11.4430
# RNF11              11.1243
#
# [5 rows x 576 columns]
#
# ----------------------------------------------
# First rows of clinical data on phenotypes;
#                  ABSOLUTE_Ploidy  ABSOLUTE_Purity  AKT1 ALK_translocation  \
# sampleID
# TCGA-05-4244-01              NaN              NaN   NaN               NaN
# TCGA-05-4249-01             3.77             0.46  none               NaN
# TCGA-05-4250-01              NaN              NaN   NaN               NaN
# TCGA-05-4382-01              NaN              NaN  none               NaN
# TCGA-05-4384-01             2.04             0.48  none               NaN
#
#                     BRAF   CBL   CTNNB1 Canonical_mut_in_KRAS_EGFR_ALK  \
# sampleID
# TCGA-05-4244-01      NaN   NaN      NaN                            NaN
# TCGA-05-4249-01  p.A762E  none     none                              Y
# TCGA-05-4250-01      NaN   NaN      NaN                            NaN
# TCGA-05-4382-01  p.L613F  none     none                              N
# TCGA-05-4384-01     none  none  p.F777S                              N
#
#                 Cnncl_mt_n_KRAS_EGFR_ALK_RET_ROS1_BRAF_ERBB2_HRAS_NRAS_AKT1_MAP2  \
# sampleID
# TCGA-05-4244-01                                                NaN
# TCGA-05-4249-01                                                  Y
# TCGA-05-4250-01                                                NaN
# TCGA-05-4382-01                                                  N
# TCGA-05-4384-01                                                  N
#
#                              EGFR  ... _GENOMIC_ID_TCGA_LUAD_exp_HiSeqV2_exon  \
# sampleID                           ...
# TCGA-05-4244-01               NaN  ...   e6a101b9-61f9-4ed1-a59f-d9db3fdb4555
# TCGA-05-4249-01              none  ...   d1a8d88d-1708-4959-9695-6f2e67853bd5
# TCGA-05-4250-01               NaN  ...   bba9333a-09f7-4585-b22e-e4ae4049f7da
# TCGA-05-4382-01  p.R222L, p.E545Q  ...   e4177b01-6898-4bb7-b38d-0c09f85c5668
# TCGA-05-4384-01              none  ...   7d6cf896-b04a-431a-a192-aaf540eeaf77
#
#                 _GENOMIC_ID_TCGA_LUAD_miRNA_HiSeq  \
# sampleID
# TCGA-05-4244-01                               NaN
# TCGA-05-4249-01                               NaN
# TCGA-05-4250-01                               NaN
# TCGA-05-4382-01                               NaN
# TCGA-05-4384-01                   TCGA-05-4384-01
#
#                  _GENOMIC_ID_TCGA_LUAD_RPPA_RBN  \
# sampleID
# TCGA-05-4244-01     TCGA-05-4244-01A-21-2190-20
# TCGA-05-4249-01     TCGA-05-4249-01A-21-2190-20
# TCGA-05-4250-01     TCGA-05-4250-01A-21-2190-20
# TCGA-05-4382-01                             NaN
# TCGA-05-4384-01     TCGA-05-4384-01A-21-2190-20
#
#                 _GENOMIC_ID_TCGA_LUAD_exp_HiSeqV2_PANCAN  \
# sampleID
# TCGA-05-4244-01     e6a101b9-61f9-4ed1-a59f-d9db3fdb4555
# TCGA-05-4249-01     d1a8d88d-1708-4959-9695-6f2e67853bd5
# TCGA-05-4250-01     bba9333a-09f7-4585-b22e-e4ae4049f7da
# TCGA-05-4382-01     e4177b01-6898-4bb7-b38d-0c09f85c5668
# TCGA-05-4384-01     7d6cf896-b04a-431a-a192-aaf540eeaf77
#
#                 _GENOMIC_ID_TCGA_LUAD_PDMRNAseq  \
# sampleID
# TCGA-05-4244-01                 TCGA-05-4244-01
# TCGA-05-4249-01                 TCGA-05-4249-01
# TCGA-05-4250-01                 TCGA-05-4250-01
# TCGA-05-4382-01                 TCGA-05-4382-01
# TCGA-05-4384-01                 TCGA-05-4384-01
#
#                            _GENOMIC_ID_TCGA_LUAD_RPPA  \
# sampleID
# TCGA-05-4244-01  59881fe3-70f4-4fa0-9355-f50250872752
# TCGA-05-4249-01  5b46a235-49a6-43ea-91b6-82a384702477
# TCGA-05-4250-01  3f069d62-c371-4f30-bdb4-c58093bbb1d7
# TCGA-05-4382-01                                   NaN
# TCGA-05-4384-01  5e735c28-5f2b-47ec-98fb-2f57cc8a5d6a
#
#                 _GENOMIC_ID_TCGA_LUAD_exp_HiSeqV2_percentile  \
# sampleID
# TCGA-05-4244-01         e6a101b9-61f9-4ed1-a59f-d9db3fdb4555
# TCGA-05-4249-01         d1a8d88d-1708-4959-9695-6f2e67853bd5
# TCGA-05-4250-01         bba9333a-09f7-4585-b22e-e4ae4049f7da
# TCGA-05-4382-01         e4177b01-6898-4bb7-b38d-0c09f85c5668
# TCGA-05-4384-01         7d6cf896-b04a-431a-a192-aaf540eeaf77
#
#                 _GENOMIC_ID_TCGA_LUAD_mutation_broad_gene  \
# sampleID
# TCGA-05-4244-01              TCGA-05-4244-01A-01D-1105-08
# TCGA-05-4249-01              TCGA-05-4249-01A-01D-1105-08
# TCGA-05-4250-01              TCGA-05-4250-01A-01D-1105-08
# TCGA-05-4382-01              TCGA-05-4382-01A-01D-1931-08
# TCGA-05-4384-01              TCGA-05-4384-01A-01D-1753-08
#
#                 _GENOMIC_ID_data/public/TCGA/LUAD/miRNA_HiSeq_gene  \
# sampleID
# TCGA-05-4244-01                                                NaN
# TCGA-05-4249-01                                                NaN
# TCGA-05-4250-01                                                NaN
# TCGA-05-4382-01                                                NaN
# TCGA-05-4384-01                                    TCGA-05-4384-01
#
#                 _GENOMIC_ID_TCGA_LUAD_miRNA_GA
# sampleID
# TCGA-05-4244-01                TCGA-05-4244-01
# TCGA-05-4249-01                TCGA-05-4249-01
# TCGA-05-4250-01                TCGA-05-4250-01
# TCGA-05-4382-01                TCGA-05-4382-01
# TCGA-05-4384-01                            NaN
#
# [5 rows x 147 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
